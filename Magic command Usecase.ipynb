# %% [markdown]
# # Data Engineers WD36 Aspirant
# **_Vashantha Kumar_**
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
# %python
displayHTML('<span style="color:blue; font-size:18px;">Hello Vashanth Good Evening</span>')

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.Usage_metrics;

# %%
# %run "/Workspace/Users/vashanth.d@gmail.com/Local Workout Notebooks/4_child_nb_dataload"

# %%
# %fs ls /Volumes/workspace/default/usage_metrics

# %%
#Task6: Create a pyspark dataframe df1 reading the data from the above file using pyspark magic command 

df1 = spark.read.csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")

# %%
#Task7: Write the above dataframe df1 data into a databricks table called 'default.mobile_os_usage' using pyspark magic command %python


#df1.write.mode("overwrite").saveAsTable("default.mobile_os_usage")
df1.write.saveAsTable("default.mobile_os_usage")

# %%
# %sql
--Task8: Write sql query to display the data loaded into the table 'default.mobile_os_usage' using the pyspark magic command %python
 
select * from default.mobile_os_usage;

# %%
#Task9: Create a python function to convert the given input to upper case

caseupper = input("Enteryour name : ")
print(caseupper.upper())

# %%
#Install pandas library using the pip python magic command %pip
# %pip install pandas

# %%
#Task11: Import pandas, using pandas read_csv and display the output using the magic command %python

import pandas as pd
df = pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
display(df)

# %%
# %sh
#Task12: echo "Magic commands tasks completed" using the linux shell magic command %sh

echo "Magic commands tasks completed"

# %%
# %python

<span style="
  background: linear-gradient(to right, red, orange, yellow, green, blue, indigo, violet);
  -webkit-background-clip: text;
  color: transparent;
  font-size: 32px;">
YourName
</span>
